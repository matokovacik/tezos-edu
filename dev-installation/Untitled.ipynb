# %% [markdown]
# # Tezos Installation Commands

# %% [markdown]
# ## Installation of prerequisites on MacOS

# %% [markdown]
# ### Install Brew a Tezos prerequisites + Libraries (In case the command is not installed)

# %%
command -v "brew">/dev/null \
 || /usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"
 
brew install \
    wget \
    pkg-config \
    hidapi \
    libev \
    telnet \
    libsodium \
    ocaml \
    opam
# Out:
# command -v "brew">/dev/null \
# .com/Homebrew/install/master/install)"ps://raw.githubusercontent
#
# brew install \
#     wget \
#     pkg-config \
#     hidapi \
#     libev \
#     telnet \
#     libsodium \
#     ocaml \
#     opam
# Warning: wget 1.19.5 is already installed and up-to-date
# To reinstall 1.19.5, run `brew reinstall wget`
# Warning: pkg-config 0.29.2 is already installed and up-to-date
# To reinstall 0.29.2, run `brew reinstall pkg-config`
# Warning: hidapi 0.8.0-rc1 is already installed and up-to-date
# To reinstall 0.8.0-rc1, run `brew reinstall hidapi`
# Warning: libev 4.24 is already installed and up-to-date
# To reinstall 4.24, run `brew reinstall libev`
# Warning: telnet 60 is already installed and up-to-date
# To reinstall 60, run `brew reinstall telnet`
# Warning: libsodium 1.0.16 is already installed and up-to-date
# To reinstall 1.0.16, run `brew reinstall libsodium`
# Error: ocaml 4.07.0_1 is already installed
# To upgrade to 4.07.1, run `brew upgrade ocaml`
# Error: opam 2.0.0 is already installed
# To upgrade to 2.0.1, run `brew upgrade opam`
# : 1

# %% [markdown]
# ### Checkout Tezos

# %%
# Checkout of the tezos source codes
mkdir -p ~/tezos-dev \
 && cd ~/tezos-dev \
 && git clone https://gitlab.com/tezos/tezos.git
# Out:
# mkdir -p ~/tezos-dev \
#  && cd ~/tezos-dev \
#  && git clone https://gitlab.com/tezos/tezos.git
# Cloning into 'tezos'...
# remote: Enumerating objects: 57780, done.
# remote: Counting objects: 100% (57780/57780), done.
# remote: Compressing objects: 100% (16778/16778), done.
# remote: Total 57780 (delta 45341), reused 50258 (delta 40743)
# Receiving objects: 100% (57780/57780), 38.01 MiB | 874.00 KiB/s, done.
# Resolving deltas: 100% (45341/45341), done.
# : 1

# %%
#Build of tezos
export OPAMYES=true
cd ~/tezos-dev/tezos
opam init --bare -n
make build-deps
# Out:
# #Build of tezos
# export OPAMYES=true
# cd ~/tezos-dev/tezos
# opam init --bare -n
# make build-deps
# [tezos] Initialisedos: git]
# # Packages matching: installed & name-match(opam-depext)
# # No matches found
# The following actions will be performed:
#   - install conf-gmp                1
#   - install mirage-no-xen           1
#   - install conf-m4                 1
#   - install conf-pkg-config         1.1
#   - install ocamlbuild              0.12.0
#   - install dune                    1.0.1
#   - install mirage-no-solo5         1
#   - install conf-perl               1
#   - install conf-libev              4-11
#   - install conf-which              1
#   - install ocamlfind               1.8.0
#   - install conf-hidapi             0
#   - install uchar                   0.0.2
#   - install jbuilder                transition
#   - install zarith                  1.7
#   - install ppx_tools               5.1+4.06.0
#   - install pprint                  20180528
#   - install ocamlgraph              1.8.8
#   - install num                     1.1
#   - install calendar                2.04
#   - install base-bytes              base
#   - install afl-persistent          1.2
#   - install result                  1.3
#   - install re                      1.7.3
#   - install ppx_traverse_builtins   v0.10.0
#   - install ppx_derivers            1.0
#   - install ocaml-compiler-libs     v0.10.0
#   - install magic-mime              1.1.0
#   - install easy-format             1.3.1
#   - install sexplib                 v0.10.0
#   - install stringext               1.5.0
#   - install cppo                    1.6.4
#   - install bigstring               0.2
#   - install base64                  2.2.0
#   - install topkg                   0.9.1
#   - install ocaml-migrate-parsetree 1.0.11
#   - install biniou                  1.2.0
#   - install cstruct                 3.2.1
#   - install base                    v0.10.0
#   - install ocplib-endian           1.0
#   - install cppo_ocamlbuild         1.6.0
#   - install rresult                 0.5.0
#   - install cmdliner                1.0.2
#   - install astring                 0.8.3
#   - install ppx_tools_versioned     5.2
#   - install ppx_ast                 v0.10.0
#   - install yojson                  1.4.1
#   - install hex                     1.2.0
#   - install stdio                   v0.10.0
#   - install ppx_deriving            4.2.1
#   - install uutf                    1.0.1
#   - install ocp-build               1.99.20-beta
#   - install fmt                     0.8.5
#   - install crowbar                 0.1
#   - install ocp-ocamlres            0.4
#   - install ocb-stubblr             0.1.1
#   - install ppx_cstruct             3.2.1
#   - install lwt                     3.3.0
#           For the PPX, please install package lwt_ppx
#           For Lwt_log and Lwt_daemon, please install package lwt_log
#   - install js_of_ocaml-compiler    3.2.0
#   - install ppx_core                v0.10.0
#   - install configurator            v0.10.0
#   - install jsonm                   1.0.1
#   - install ocp-indent              1.6.1
#   - install alcotest                0.8.3
#   - install cpuid                   0.1.1
#   - install cstruct-lwt             3.2.1
#   - install js_of_ocaml             3.2.0
#   - install ppx_optcomp             v0.10.0
#   - install hidapi                  1.0-1
#   - install ezjsonm                 0.6.0
#   - install ptime                   0.8.3
#   - install mtime                   1.1.0
#   - install logs                    0.6.2
#   - install ppx_driver              v0.10.4
#   - install asn1-combinators        0.2.0
#   - install alcotest-lwt            0.8.0
#   - install ppx_metaquot            v0.10.0
#   - install fieldslib               v0.10.0
#   - install ppx_type_conv           v0.10.0
#   - install ppx_sexp_conv           v0.10.0
#   - install ppx_fields_conv         v0.10.0
#   - install uri                     1.9.7
#   - install nocrypto                0.5.4-1
#   - install ipaddr                  2.8.0
#   - install irmin                   1.4.0
#   - install cohttp                  1.1.0
#   - install x509                    0.6.1
#   - install conduit                 1.1.0
#   - install cohttp-lwt              1.0.2
#   - install tls                     0.9.1
#   - install conduit-lwt             1.1.0
#   - install conduit-lwt-unix        1.1.0
#   - install cohttp-lwt-unix         1.0.2
# ===== 93 to install =====
#
# <><> Gathering sources ><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# [afl-persistent.1.2] found in cache
# [alcotest.0.8.3] found in cache
# [alcotest-lwt.0.8.0] found in cache
# [asn1-combinators.0.2.0] found in cache
# [astring.0.8.3] found in cache
# [base.v0.10.0] found in cache
# [base64.2.2.0] found in cache
# [bigstring.0.2] found in cache
# [biniou.1.2.0] found in cache
# [calendar.2.04] found in cache
# [cmdliner.1.0.2] found in cache
# [cohttp.1.1.0] found in cache
# [cohttp-lwt.1.0.2] found in cache
# [cohttp-lwt-unix.1.0.2] found in cache
# [conduit.1.1.0] found in cache
# [conduit-lwt.1.1.0] found in cache
# [conduit-lwt-unix.1.1.0] found in cache
# [configurator.v0.10.0] found in cache
# [cppo.1.6.4] found in cache
# [cppo_ocamlbuild.1.6.0] found in cache
# [cpuid.0.1.1] found in cache
# [crowbar.0.1] found in cache
# [cstruct.3.2.1] found in cache
# [cstruct-lwt.3.2.1] found in cache
# [dune.1.0.1] found in cache
# [easy-format.1.3.1] found in cache
# [ezjsonm.0.6.0] found in cache
# [fieldslib.v0.10.0] found in cache
# [fmt.0.8.5] found in cache
# [hex.1.2.0] found in cache
# [hidapi.1.0-1] found in cache
# [ipaddr.2.8.0] found in cache
# [irmin.1.4.0] found in cache
# [js_of_ocaml.3.2.0] found in cache
# [js_of_ocaml-compiler.3.2.0] found in cache
# [jsonm.1.0.1] found in cache
# [logs.0.6.2] found in cache
# [lwt.3.3.0] found in cache
# [magic-mime.1.1.0] found in cache
# [mtime.1.1.0] found in cache
# [nocrypto.0.5.4-1] found in cache
# [num.1.1] found in cache
# [ocaml-compiler-libs.v0.10.0] found in cache
# [ocaml-migrate-parsetree.1.0.11] found in cache
# [ocamlbuild.0.12.0] found in cache
# [ocamlfind.1.8.0] found in cache
# [ocamlgraph.1.8.8] found in cache
# [ocb-stubblr.0.1.1] found in cache
# [ocp-build.1.99.20-beta] found in cache
# [ocp-indent.1.6.1] found in cache
# [ocp-ocamlres.0.4] found in cache
# [ocplib-endian.1.0] found in cache
# [pprint.20180528] found in cache
# [ppx_ast.v0.10.0] found in cache
# [ppx_core.v0.10.0] found in cache
# [ppx_cstruct.3.2.1] found in cache
# [ppx_derivers.1.0] found in cache
# [ppx_deriving.4.2.1] found in cache
# [ppx_driver.v0.10.4] found in cache
# [ppx_fields_conv.v0.10.0] found in cache
# [ppx_metaquot.v0.10.0] found in cache
# [ppx_optcomp.v0.10.0] found in cache
# [ppx_sexp_conv.v0.10.0] found in cache
# [ppx_tools.5.1+4.06.0] found in cache
# [ppx_tools_versioned.5.2] found in cache
# [ppx_traverse_builtins.v0.10.0] found in cache
# [ppx_type_conv.v0.10.0] found in cache
# [ptime.0.8.3] found in cache
# [re.1.7.3] found in cache
# [result.1.3] found in cache
# [rresult.0.5.0] found in cache
# [sexplib.v0.10.0] found in cache
# [stdio.v0.10.0] found in cache
# [stringext.1.5.0] found in cache
# [tls.0.9.1] found in cache
# [topkg.0.9.1] found in cache
# [uchar.0.0.2] found in cache
# [uri.1.9.7] found in cache
# [uutf.1.0.1] found in cache
# [x509.0.6.1] found in cache
# [yojson.1.4.1] found in cache
# [zarith.1.7] found in cache
# Processing 93/93:
# <><> Processing actions <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# -> installed conf-gmp.1m: ocaml bootstrap.ml] [ocamlbuild: make configure.make] m4]
# -> installed conf-libev.4-11aml bootstrap.ml] [ocamlbuild: make configure.make]
# -> installed conf-m4.10m: ocaml bootstrap.ml] [ocamlbuild: make configure.make]
# -> installed conf-perl.1: ./boot.exe 3]                                     + 1ure.make]
# -> installed conf-pkg-config.1.1.exe 3]                                     + 1
# -> installed conf-hidapi.0./boot.exe 3]                                     + 13]    + 1
# -> installed conf-which.1 ./boot.exe 3]                                     + 1
# -> installed mirage-no-solo5.1ot.exe 3]                                     + 1
# -> installed mirage-no-xen.1boot.exe 3]                                     + 1
# -> installed ocamlfind.1.8.0boot.exe 3]                                     + 2
# -> installed afl-persistent.1.2t.exe 3] [ocamlgraph: make] [zarith: make]ch]
# -> installed base-bytes.baseboot.exe 3] [ocamlgraph: make]
# -> installed calendar.2.04./boot.exe 3] [ocamlgraph: make]                  + 1
# -> installed num.1.1: ./boot.exe 3] [ocamlgraph: make] [num: make install]
# -> installed ocamlbuild.0.12.0ot.exe 3] [ocamlgraph: make]
# -> installed dune.1.0.1aph: make] [pprint: make all] [uchar: ocaml]e all]
# -> installed jbuilder.transitionmake] [pprint: make all]
# -> installed base64.2.2.0builder build] [sexplib: jbuilder build]           + 1
# -> installed bigstring.0.2uilder build] [sexplib: jbuilder build]
# -> installed cppo.1.6.4 jbuilder build] [sexplib: jbuilder build]
# -> installed cppo_ocamlbuild.1.6.0 ocaml setup.ml] [sexplib: jbuilder build]d]1
# -> installed easy-format.1.3.1: ocaml setup.ml] [sexplib: jbuilder build]
# -> installed magic-mime.1.1.0builder build] [ocplib-endian: ocaml setup.ml] + 1
# -> installed ocaml-compiler-libs.v0.10.0ld] [ocplib-endian: ocaml setup.ml]
# -> installed ocamlgraph.1.8.8: ocaml setup.ml]                          + 1p.ml] + 1
# -> installed biniou.1.2.0dian: ocaml setup.ml]
# -> installed pprint.20180528n: ocaml setup.ml] [yojson: jbuilder build] + 1
# -> installed ppx_derivers.1.0: ocaml setup.ml] [yojson: jbuilder build]
# -> installed ppx_tools.5.1+4.06.0: ocaml setup.ml] [yojson: jbuilder build] + 1
# -> installed ppx_traverse_builtins.v0.10.0etup.ml] [yojson: jbuilder build]
# -> installed re.1.7.3b-endian: ocaml setup.ml] [yojson: jbuilder build]
# -> installed result.1.3endian: ocaml setup.ml] [yojson: jbuilder build]
# -> installed ocplib-endian.1.0parsetree: jbuilder build]                + 2uild]
# -> installed sexplib.v0.10.0e-parsetree: jbuilder build]                + 1
# -> installed ocaml-migrate-parsetree.1.0.11cstruct: jbuilder build]         + 1
# -> installed cstruct.3.2.1jbuilder build] [ppx_tools_versioned: jbuilder build]
# -> installed base.v0.10.0jbuilder build] [ppx_tools_versioned: jbuilder build]1
# -> installed hex.1.2.0ols_versioned: jbuilder build]                    + 1r build]
# -> installed ppx_ast.v0.10.0rsioned: jbuilder build]                    + 1
# -> installed ppx_deriving.4.2.1oned: jbuilder build]                    + 1
# -> installed stringext.1.5.0rsioned: jbuilder build]                    + 1
# -> installed topkg.0.9.1s_versioned: jbuilder build]                    + 1
# -> installed ppx_tools_versioned.5.2uild] [cmdliner: ocaml build]           + 1
# -> installed astring.0.8.3builder build] [ppx_cstruct: jbuilder build]      + 1
# -> installed cmdliner.1.0.2uilder build] [ocp-ocamlres: make all]           + 1
# -> installed crowbar.0.1: jbuilder build] [ocp-build: ./configure]          + 1
# -> installed ocb-stubblr.0.1.1lder build] [ocp-build: ./configure]
# -> installed cpuid.0.1.1: jbuilder build] [ocp-build: make]ld]              + 1
# -> installed ocp-ocamlres.0.4ilder build] [ocp-build: make]                 + 1
# -> installed ppx_cstruct.3.2.1lder build] [ocp-build: make]
# -> installed rresult.0.5.0jbuilder build] [ocp-build: make]
# -> installed stdio.v0.10.0jbuilder build] [ocp-build: make]
# -> installed configurator.v0.10.0ake] [ppx_core: jbuilder build]ake]        + 1
# -> installed hidapi.1.0-1d: make] [ppx_core: jbuilder build]            + 1
# -> installed lwt.3.3.0uild: make] [ppx_core: jbuilder build]
# -> installed cstruct-lwt.3.2.1: make] [ppx_core: jbuilder build]ke]         + 1
# -> installed uchar.0.0.2ld: make] [ppx_core: jbuilder build]
# -> installed ppx_core.v0.10.0ml build] [ocp-build: make] [uutf: ocaml build]
# -> installed fmt.0.8.5uild: make] [ppx_optcomp: jbuilder build]         + 1
# -> installed alcotest.0.8.3: make] [ppx_optcomp: jbuilder build]         + 1
# -> installed uutf.1.0.1ild: make] [ppx_optcomp: jbuilder build]
# -> installed ppx_optcomp.v0.10.0l build] [ocp-build: make]                  + 1
# -> installed jsonm.1.0.1ld: make] [ppx_driver: jbuilder build]          + 1
# -> installed ezjsonm.0.6.0: make] [ppx_driver: jbuilder build]          + 1
# -> installed yojson.1.4.1d: make] [ppx_driver: jbuilder build]
# -> installed ppx_driver.v0.10.4mpiler: jbuilder build] [ocp-build: make]
# -> installed fieldslib.v0.10.0ompiler: jbuilder build] [ocp-build: make]
# -> installed ppx_metaquot.v0.10.0iler: jbuilder build] [ocp-build: make]
# -> installed ppx_type_conv.v0.10.0ler: jbuilder build] [ocp-build: make]
# -> installed js_of_ocaml-compiler.3.2.0ppx_sexp_conv: jbuilder build]d]     + 1
# -> installed ppx_fields_conv.v0.10.0uilder build] [ocp-build: make]         + 1
# -> installed ppx_sexp_conv.v0.10.0jbuilder build] [ocp-build: make]
# -> installed ipaddr.2.8.0aml: jbuilder build] [uri: jbuilder build]ld]  + 1
# -> installed ocp-build.1.99.20-betae install]ild] [ocp-build: make install] + 1
# -> installed js_of_ocaml.3.2.0m: ./configure]
# -> installed logs.0.6.2dent: make] [ptime: ocaml build]                 + 10m: make]
# -> installed mtime.1.1.0t-lwt: jbuilder build] [ptime: ocaml build]     + 1
# -> installed ocp-indent.1.6.1: jbuilder build] [ptime: ocaml build]
# -> installed uri.1.9.7est-lwt: jbuilder build] [ptime: ocaml build]
# -> installed alcotest-lwt.0.8.0uilder build] [irmin: jbuilder build]d]      + 1
# -> installed conduit.1.1.0m: jbuilder build] [irmin: jbuilder build]
# -> installed cohttp.1.1.0lwt: jbuilder build] [irmin: jbuilder build]]  + 1
# -> installed conduit-lwt.1.1.0m: jbuilder build] [irmin: jbuilder build]]
# -> installed ptime.0.8.3lwt: jbuilder build] [irmin: jbuilder build]
# -> installed zarith.1.7-lwt: jbuilder build] [zarith: make install]]    + 1
# -> installed cohttp-lwt.1.0.2tors: ocaml build] [nocrypto: patch]2
# -> installed irmin.1.4.0mbinators: ocaml build] [nocrypto: patch]
# -> installed asn1-combinators.0.2.0h]: ocaml build] [nocrypto: patch]
# -> installed nocrypto.0.5.4-1: ocaml build]
# -> installed x509.0.6.10m: ocaml build]
# -> installed tls.0.9.10m: ocaml build]
# -> installed conduit-lwt-unix.1.1.00m: jbuilder build]
# -> installed cohttp-lwt-unix.1.0.20m: jbuilder build]
# Done.
#
# <><> ocp-indent.1.6.1 installed successfully ><><><><><><><><><><><><><><><><><>
# => This package requires additional configuration for use in editors. Install
#    package 'user-setup', or manually:
#
#    * for Emacs, add these lines to ~/.emacs:
#      (add-to-list 'load-path
#    "/Users/martinkovacik/tezos-dev/tezos/_opam/share/emacs/site-lisp")
#      (require 'ocp-indent)
#
#    * for Vim, add this line to ~/.vimrc:
#      set rtp^="/Users/martinkovacik/tezos-dev/tezos/_opam/share/ocp-indent/vim"
#
# <><> jbuilder.transition installed successfully <><><><><><><><><><><><><><><><>
# => Jbuilder has been renamed and the jbuilder package is now a transition
#    package. Use the dune package instead.
#
# <><> afl-persistent.1.2 installed successfully ><><><><><><><><><><><><><><><><>
# => afl-persistent is installed, but since the current OCaml compiler does
#    not enable AFL instrumentation by default, most packages will not be
#    instrumented and fuzzing with afl-fuzz may not be effective.
#
#    To globally enable AFL instrumentation, use an OCaml switch such as
#    4.04.0+afl.
# : 1

# %%
make
# Out:
# make
# Info: creating file dune-project with this contents: (lang dune 1.5)
# Info: creating file src/bin_client/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/bin_node/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/bin_signer/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_base/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_clic/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_client_base/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_client_base_unix/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_client_commands/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_crypto/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_data_encoding/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_error_monad/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_micheline/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_p2p/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_protocol_compiler/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_protocol_environment/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_protocol_updater/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_rpc/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_rpc_http/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_shell/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_shell_services/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_signer_backends/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_signer_services/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_stdlib/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_stdlib_unix/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_storage/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/lib_validation/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/bin_accuser/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/bin_baker/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/bin_endorser/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/lib_client/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/lib_client_commands/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/lib_delegate/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_alpha/lib_protocol/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_demo/lib_protocol/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_genesis/lib_client/dune-project with this contents: (lang dune 1.5)
# Info: creating file src/proto_genesis/lib_protocol/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/irmin-lmdb/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-bip39/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-blake2/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-hacl/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-ledger-wallet/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-lmdb/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-pbkdf/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-secp256k1/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocaml-uecc/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-json-typed/lib_json_typed/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-json-typed/lib_json_typed_browser/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-json-typed/lib_json_typed_bson/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_ezresto/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_ezresto-directory/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_resto/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_resto-cohttp/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_resto-directory/dune-project with this contents: (lang dune 1.5)
# Info: creating file vendors/ocplib-resto/lib_resto-json/dune-project with this contents: (lang dune 1.5)
# File "src/lib_base/dune", line 24, characters 12-26:
# 24 |             mtime.clock.os
#                  ^^^^^^^^^^^^^^
# Error: Library "mtime.clock.os" not found.
# Hint: try: dune external-lib-deps --missing src/bin_node/main.exe src/bin_client/main_client.exe src/bin_client/main_admin.exe src/bin_signer/main_signer.exe src/lib_protocol_compiler/main_native.exe src/proto_alpha/bin_baker/main_baker_alpha.exe src/proto_alpha/bin_endorser/main_endorser_alpha.exe src/proto_alpha/bin_accuser/main_accuser_alpha.exe
# File "src/bin_node/dune", line 15, characters 12-15:
# 15 |             tls)
#                  ^^^
# Error: Library "tls" not found.
# Hint: try: dune external-lib-deps --missing src/bin_node/main.exe src/bin_client/main_client.exe src/bin_client/main_admin.exe src/bin_signer/main_signer.exe src/lib_protocol_compiler/main_native.exe src/proto_alpha/bin_baker/main_baker_alpha.exe src/proto_alpha/bin_endorser/main_endorser_alpha.exe src/proto_alpha/bin_accuser/main_accuser_alpha.exe
# make: *** [all] Error 1
# : 1
